# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import QuantileTransformer, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from imblearn.under_sampling import RandomUnderSampler
import seaborn as sns

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.Exited.value_counts().plot(kind="bar")
plt.show()

# %%
under_sampler = RandomUnderSampler(random_state=9)
X_resampled, y_resampled = under_sampler(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 under_sampler = RandomUnderSampler(random_state=9)
# ----> 2 X_resampled, y_resampled = under_sampler(X, y)
#
# NameError: name 'X' is not defined

# %%
df.CreditScore.plot(kind="hist")
plt.show()

# %%
df.Balance.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.Tenure.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.EstimatedSalary.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
columns_drop = ["RowNumber", "CustomerId", "Geography", "Surname", "Gender"]
df_correlation = df.drop(columns_drop, axis=1)
import seaborn as sns

corr_matrix = df_correlation.corr()
sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.Age.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
Age_new = QuantileTransformer().fit_transform(df[["Age"]])

Age_new_scaled = StandardScaler().fit_transform(Age_new)
Age_new_df = pd.DataFrame(Age_new_scaled, columns=["Age"])

Age_new_df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
numerical_cols = df.select_dtypes(include=["float64", "int64"]).columns.tolist()
# numerical_cols = X.columns.tolist()
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,20), constrained_layout = False)

i = j = 0

for column in numerical_cols:
    sns.kdeplot(data=df, x=df[column], y=df["Exited"],fill=True, ax=axes[i, j])

    if j == 1:
        j = 0
        i += 1
    else:
        j += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 8
#       5 i = j = 0
#       7 for column in numerical_cols:
# ----> 8     sns.kdeplot(data=df, x=df[column], y=df["Exited"],fill=True, ax=axes[i, j])
#      10     if j == 1:
#      11         j = 0
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
df.
